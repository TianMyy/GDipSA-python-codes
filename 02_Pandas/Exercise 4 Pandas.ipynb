# %% [markdown]
# # Exercise 4 Pandas

# %% [markdown]
# 1) Import pandas package;
#    import pyplot of matplotlib package;
#    import seaborn package

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# 2) Load AMZN.csv into dataframe df

# %%
df = pd.read_csv('D:\SA-NUS\Python\Python ML 1 (Yuen Kwan)\Codes (Python)\Workshop\AMZN.csv')
df
# Out:
#           Date  ClosingPrice   Volume
# 0    18/9/2018   1941.050049  4268700
# 1    19/9/2018   1926.420044  4056800
# 2    20/9/2018   1944.300049  3154900
# 3    21/9/2018   1915.010010  6855900
# 4    24/9/2018   1934.359985  4213700
# ..         ...           ...      ...
# 246  11/9/2019   1822.989990  2432800
# 247  12/9/2019   1843.550049  2823500
# 248  13/9/2019   1839.339966  1971300
# 249  16/9/2019   1807.839966  3675500
# 250  17/9/2019   1822.550049  1982400
#
# [251 rows x 3 columns]

# %% [markdown]
# 3) Plots the Closing Price

# %%
df.ClosingPrice.plot()
plt.show()

# %% [markdown]
# 4) Plot the closing price with x ='Date', y= 'ClosingPrice'

# %%
df.plot(x='Date',y='ClosingPrice')
plt.show()

# %% [markdown]
# 5) Plot a scatter plot with Closing Price against Volume

# %%
df.plot.scatter(x='Volume',y='ClosingPrice',label='Volume vs ClosingProce')
plt.show()

# %% [markdown]
# 6) Load order_details.csv into the dataframe df_order

# %%
df_order = pd.read_csv('D:\SA-NUS\Python\Python ML 1 (Yuen Kwan)\Codes (Python)\Workshop\order-details.csv')
df_order
# Out:
#       OrderID  ProductID  UnitPrice  Quantity  Discount
# 0       10248         11      14.00        12      0.00
# 1       10248         42       9.80        10      0.00
# 2       10248         72      34.80         5      0.00
# 3       10249         14      18.60         9      0.00
# 4       10249         51      42.40        40      0.00
# ...       ...        ...        ...       ...       ...
# 2150    11077         64      33.25         2      0.03
# 2151    11077         66      17.00         1      0.00
# 2152    11077         73      15.00         2      0.01
# 2153    11077         75       7.75         4      0.00
# 2154    11077         77      13.00         2      0.00
#
# [2155 rows x 5 columns]

# %% [markdown]
# 7) Display the spread of unit price in histogram

# %%
df_order['UnitPrice'].hist()
plt.show()

# %% [markdown]
# 8) Load SalesData.csv into the dataframe df (Hint: encoding='ISO-8859-1')

# %%
df = pd.read_csv('D:\SA-NUS\Python\Python ML 1 (Yuen Kwan)\Codes (Python)\Workshop\SalesData.csv',encoding='ISO-8859-1')
df
# Out:
#      Order ID Order Date  Customer ID Customer Name          Address  \
# 0        1001   01/27/14           27    Company AA  789 27th Street
# 1        1002   01/27/14           27    Company AA  789 27th Street
# 2        1003   1/4/2014            4     Company D   123 4th Street
# 3        1004   1/4/2014            4     Company D   123 4th Street
# 4        1005   1/4/2014            4     Company D   123 4th Street
# ..        ...        ...          ...           ...              ...
# 364      1428   12/29/14           29    Company CC  789 29th Street
# 365      1429  12/6/2014            6     Company F   123 6th Street
# 366      1430  12/6/2014            6     Company F   123 6th Street
# 367      1431  12/4/2014            4     Company D   123 4th Street
# 368      1432  12/3/2014            3     Company C   123 3rd Street
#
#             City State  ZIP/Postal Code Country/Region Shipped Date  ...  \
# ...

# %% [markdown]
# 9) Use scatter plot to display the relations between revenue and shipping fee.

# %%
df.plot.scatter(x='Shipping Fee',y='Revenue',label='Shipping Fee vs Revenue')
plt.show()

# %% [markdown]
# 10) How many rows are there with empty Shipper Name?

# %%
df.loc[(df['Shipper Name'].isnull())]
# Out:
#      Order ID Order Date  Customer ID Customer Name         Address  \
# 15       1016   1/7/2014            7     Company G  123 7th Street
# 21       1022   1/1/2014            1     Company A  123 1st Street
# 22       1023   1/1/2014            1     Company A  123 1st Street
# 23       1024   1/1/2014            1     Company A  123 1st Street
# 48       1050   2/4/2014            4     Company D  123 4th Street
# 49       1051   2/3/2014            3     Company C  123 3rd Street
# 82       1092   4/7/2014            7     Company G  123 7th Street
# 88       1098   4/1/2014            1     Company A  123 1st Street
# 95       1105   5/7/2014            7     Company G  123 7th Street
# 101      1111   5/1/2014            1     Company A  123 1st Street
# 102      1112   5/1/2014            1     Company A  123 1st Street
# 103      1113   5/1/2014            1     Company A  123 1st Street
# 122      1138   6/7/2014            7     Company G  123 7th Street
# ...

# %% [markdown]
# 11) Display customer id and customer name for those without shipper name.

# %%
df[['Customer ID','Customer Name']].loc[(df['Shipper Name'].isnull())]
# Out:
#      Customer ID Customer Name
# 15             7     Company G
# 21             1     Company A
# 22             1     Company A
# 23             1     Company A
# 48             4     Company D
# 49             3     Company C
# 82             7     Company G
# 88             1     Company A
# 95             7     Company G
# 101            1     Company A
# 102            1     Company A
# 103            1     Company A
# 122            7     Company G
# 128            1     Company A
# 129            1     Company A
# 130            1     Company A
# 162            4     Company D
# 163            3     Company C
# 164            1     Company A
# 193            7     Company G
# 199            1     Company A
# 200            1     Company A
# 201            1     Company A
# 220            1     Company A
# 221            1     Company A
# 222            1     Company A
# 246            7     Company G
# 252            1     Company A
# 253            1     Company A
# ...

# %% [markdown]
# 12) Drop those rows with empty shipper name from the dataframe.  Count the number of rows to verify the number of <bf>
#     records in the dataframe.

# %%
df.count()
# Out:
# Order ID                369
# Order Date              369
# Customer ID             369
# Customer Name           369
# Address                 369
# City                    369
# State                   369
# ZIP/Postal Code         369
# Country/Region          369
# Shipped Date            291
# Shipper Name            330
# Ship Name               369
# Ship Address            369
# Ship City               369
# Ship State              369
# Ship ZIP/Postal Code    369
# Ship Country/Region     369
# Payment Type            267
# Product Name            366
# Category                366
# Unit Price              366
# Quantity                366
# Revenue                 369
# Shipping Fee            369
# dtype: int64

# %%
df = df.dropna(subset=['Shipper Name'])
df.count()
# Out:
# Order ID                330
# Order Date              330
# Customer ID             330
# Customer Name           330
# Address                 330
# City                    330
# State                   330
# ZIP/Postal Code         330
# Country/Region          330
# Shipped Date            291
# Shipper Name            330
# Ship Name               330
# Ship Address            330
# Ship City               330
# Ship State              330
# Ship ZIP/Postal Code    330
# Ship Country/Region     330
# Payment Type            267
# Product Name            327
# Category                327
# Unit Price              327
# Quantity                327
# Revenue                 330
# Shipping Fee            330
# dtype: int64

# %% [markdown]
# 13) Retrieve total revenue by customer id

# %%
total_revenue = df.groupby(['Customer ID'])
total_revenue['Revenue'].sum()
# Out:
# Customer ID
# 1      6348.00
# 3     26446.25
# 4     58060.50
# 6     37418.00
# 8     50198.35
# 9     32530.60
# 10    29133.01
# 11    21937.08
# 12    14074.00
# 25    11962.00
# 26    28208.25
# 27     1291.50
# 28    43703.00
# 29    16350.50
# Name: Revenue, dtype: float64
