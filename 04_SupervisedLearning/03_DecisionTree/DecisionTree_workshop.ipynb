# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib as plt

# %%
iris=pd.read_csv('iris-data-clean.csv')
df=iris.replace(['Setosa','Virginica','Versicolor'],[0,1,2])
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  class
# 0                5.1             3.5              1.4             0.2      0
# 1                4.9             3.0              1.4             0.2      0
# 2                4.7             3.2              1.3             0.2      0
# 3                4.6             3.1              1.5             0.2      0
# 4                5.0             3.6              1.4             0.2      0
# ..               ...             ...              ...             ...    ...
# 140              6.7             3.0              5.2             2.3      1
# 141              6.3             2.5              5.0             1.9      1
# 142              6.5             3.0              5.2             2.0      1
# 143              6.2             3.4              5.4             2.3      1
# 144              5.9             3.0              5.1             1.8      1
#
# [145 rows x 5 columns]

# %%
X=df.iloc[:,0:4]
y=df['class']
print(X)
print(y)
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 140              6.7             3.0              5.2             2.3
# 141              6.3             2.5              5.0             1.9
# 142              6.5             3.0              5.2             2.0
# 143              6.2             3.4              5.4             2.3
# 144              5.9             3.0              5.1             1.8
#
# [145 rows x 4 columns]
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 140    1
# 141    1
# 142    1
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (108, 4)
# (37, 4)
# (108,)
# (37,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dt=DecisionTreeClassifier()
model=dt.fit(X_train,y_train)

# %%
y_pre=model.predict(X_test)
print(accuracy_score(y_test,y_pre))
# Out:
# 0.918918918918919

# %%
from sklearn import tree
import graphviz
from graphviz import Source

# %%
Source(tree.export_graphviz(dt,out_file=None,class_names=True,feature_names=X_train.columns))

# %%
Source(tree.export_graphviz(dt,out_file=None,class_names=['No','Yes'],feature_names=X_train.columns))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-f67c354dde08> in <module>
# ----> 1 Source(tree.export_graphviz(dt,out_file=None,class_names=['No','Yes'],feature_names=X_train.columns))
#
# D:\DownloadApp\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# D:\DownloadApp\Anaconda\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     781             rounded=rounded, special_characters=special_characters,
# ...
